# %%
import os

def print_folder_structure(root_folder, indent=0):
    for item in os.listdir(root_folder):
        path = os.path.join(root_folder, item)
        print('    ' * indent + '|-- ' + item)
        if os.path.isdir(path):
            print_folder_structure(path, indent + 1)

# 사용 예시
root_path = '.'  # 현재 폴더를 기준으로 출력
print_folder_structure(root_path)
# Out:
# |-- .git
#     |-- COMMIT_EDITMSG
#     |-- config
#     |-- description
#     |-- FETCH_HEAD
#     |-- HEAD
#     |-- hooks
#         |-- applypatch-msg.sample
#         |-- commit-msg.sample
#         |-- fsmonitor-watchman.sample
#         |-- post-update.sample
#         |-- pre-applypatch.sample
#         |-- pre-commit.sample
#         |-- pre-merge-commit.sample
#         |-- pre-push.sample
#         |-- pre-rebase.sample
#         |-- pre-receive.sample
#         |-- prepare-commit-msg.sample
#         |-- push-to-checkout.sample
#         |-- sendemail-validate.sample
#         |-- update.sample
#     |-- index
#     |-- info
#         |-- exclude
#     |-- logs
#         |-- HEAD
#         |-- refs
#             |-- heads
#                 |-- main
#             |-- remotes
#                 |-- origin
#                     |-- HEAD
#                     |-- main
#     |-- objects
#         |-- 00
#             |-- 89fcf92800d58265772fce5b350611371af0a0
#         |-- 02
#             |-- 1e08cda760213459bfad6d0bcb84f1f0711487
#         |-- 03
#             |-- 3c671d13c2a6826ea14320ea2fec170532cdf0
#         |-- 06
#             |-- 0414068872587dfad5d948c214b29704f6f5e5
#         |-- 0b
#             |-- 457a8f9ca0b27024e5ded6b1ad1b1d29adff5e
#             |-- 72f2263cafc688337ec7771b282e261fe39437
#         |-- 0e
#             |-- 18a50035c4832910fa8e96d45524fda38c1bfc
#             |-- 59d2f46f5611b846acc519c0257cd1a6ab7831
#         |-- 0f
#             |-- 6e0f7ecec216f4278ce0d20f9c56a485ab099b
#             |-- 944822a9c81fe1b43bb9181732c6a2e4942139
#         |-- 17
#             |-- 26be232c67d160c6a9fed4a6dd7066c6e35127
#         |-- 18
#             |-- 96b8b69875279d38f8ee7a1deabd896c21b2aa
#             |-- e6e6e0b17ee8bcedb0957afaf80fe1305c5d2d
#         |-- 19
#             |-- 3bd6603ad57e37539e3de1b6d9f66456513380
#         |-- 1d
#             |-- bbe646dc05452cd159720e20cf2ede315060e0
#         |-- 1e
#             |-- 285804e4b2992f5f21ea7c0bf4a77303b168de
#         |-- 29
#             |-- 68f827be0fed75963427d60b23d17adeff0457
#         |-- 2b
#             |-- d90cad43fc795023f285d9637dceaf1d805563
#         |-- 2c
#             |-- e7946acb6ac5612a5df2b6899d6cb54b20b3dc
#         |-- 2d
#             |-- e947fd03e2756ce26e90ad3daf41e069720406
#         |-- 2e
#             |-- 7c916b42fc7ccea4a7cc742c350e1932f0e98c
#         |-- 37
#             |-- 854f75e665f1c6de61c662285b4823dc874fd4
#         |-- 38
#             |-- b7d3c047ef3fc3cd609e449a92ccf20b82c239
#             |-- fae6f6b8ddd54d2c9bc6f0015944e48ade6493
#         |-- 3a
#             |-- a480154e528df7eae9fa6472f460468e30f866
#         |-- 3f
#             |-- 8c605f6cca0926a0d06edead373a75045a4333
#         |-- 43
#             |-- 6aed9a817d9721de5042faebc1485c651db6e0
#         |-- 49
#             |-- 72de4edd02e0efa84acdd3f630a164cd5bcacd
#         |-- a1
#             |-- eb4e89e89339a51b90cfde5fdc9900352c2781
#         |-- a9
#             |-- 4e3ec14b1318ee60ce39d1f75abdda5042e3fa
#         |-- bc
#             |-- 327e6fbbb2dc131d0e04ad7f220d8133ae4e1a
#         |-- bd
#             |-- 7cf33d838d8a7a691cff63b4ac5c87c092bc91
#         |-- bf
#             |-- bb071945b2e0d6533d3e03effe6c858c327bda
#         |-- c1
#             |-- f26946841a66a32561f8600fa6c029d848dc88
#         |-- c2
#             |-- 15505bde96c1c3a900aee91035105dacd1faea
#         |-- c3
#             |-- 1d356907764f6bf8b58604658e22ff2cabda1f
#             |-- bfa17dfab41569224b43edf48de966726463e6
#         |-- c6
#             |-- 3ba3cdcfae7b3438781fe021c0e232f134ef1a
#             |-- c9e0311024ce35bc988f4225f813cbc659fbd8
#         |-- c8
#             |-- f2d8ca9d45ff6a1e857be8e937cdfa82761ffd
#         |-- cb
#             |-- 7d5ed4e0d1fca325dd911a97c7afbd6ef5ab2e
#             |-- 7e5f57f2181b8127c5e06e423096c477b3ce68
#         |-- cf
#             |-- 1b1fc2dd1eada1c3dc08f35efc69b8c337aea2
#         |-- d0
#             |-- 9e5a9d9e83386f9b595c996e1d958767ef9f07
#             |-- a3c5e9258b4eaf3aa99359f09cda19f59272c2
#         |-- d3
#             |-- 43d9fc325fe4432b40af0ace8474d5e52297bc
#         |-- d5
#             |-- 81c0d211302031b04fd2a0402ecfba4783395a
#         |-- d9
#             |-- f44733b82dab0f25e2bf57ed9e16611ab8976e
#         |-- da
#             |-- 74b3c563172a050544b04b1ad6e648399be8e4
#         |-- db
#             |-- 8e31bb9872c60c9577cc26aa7ddc8aa03020cb
#         |-- dc
#             |-- 36f89b1e687d2800b4043cb35b40c0bd51262e
#             |-- 6b8bcaf6bb0fad003359d736d3d93efe118545
#         |-- de
#             |-- aa2e4aec94ff0f3a0c3462acbf43178789d9ce
#         |-- df
#             |-- e0770424b2a19faf507a501ebfc23be8f54e7b
#         |-- e0
#             |-- b4eac61678794abab4935cd60fd6d3a219991e
#         |-- e1
#             |-- 22deb1d1b981ee142ad9f63b6ed30ed3aa0708
#         |-- e2
#             |-- 3854c11d27b0354e0008605c78feb02cf1b0a4
#         |-- ec
#             |-- e86a60b6e542c29579ef2ddedb4553656786e7
#         |-- f1
#             |-- dfb5fcb63d2560cd84b5741db32f7d22f2d7a7
#         |-- fb
#             |-- 13133992055ff387f3d2354a4e5f116419ae38
#         |-- info
#         |-- pack
#     |-- refs
#         |-- heads
#             |-- main
#         |-- remotes
#             |-- origin
#                 |-- HEAD
#                 |-- main
#         |-- tags
# |-- .gitattributes
# |-- ETC.ipynb
# |-- README.md
# |-- 데이터
#     |-- 중도탈락 학생 현황_학과별
#         |-- 공학계열
#             |-- 전처리 전
#                 |-- 2022_대학_공학계열.xlsx
#                 |-- 2022_전문대_공학계열.xlsx
#                 |-- 2023_대학_공학계열.xlsx
#                 |-- 2023_전문대_공학계열.xlsx
#                 |-- 2024_대학_공학계열.xlsx
#                 |-- 2024_전문대_공학계열.xlsx
#             |-- 전처리 후
#                 |-- 2022_대학_공학계열.xlsx
#                 |-- 2022_전문대_공학계열.xlsx
#                 |-- 2023_대학_공학계열.xlsx
#                 |-- 2023_전문대_공학계열.xlsx
#                 |-- 2024_대학_공학계열.xlsx
#                 |-- 2024_전문대_공학계열.xlsx
#         |-- 소속없음
#             |-- 2022_대학.xlsx
#             |-- 2022_전문대.xlsx
#             |-- 2023_대학.xlsx
#             |-- 2023_전문대.xlsx
#             |-- 2024_대학.xlsx
#             |-- 2024_전문대.xlsx
#         |-- 예체능계열
#             |-- 전처리 전
#                 |-- 2022_대학_예체능계열.xlsx
#                 |-- 2022_전문대_예체능계열.xlsx
#                 |-- 2023_대학_예체능계열.xlsx
#                 |-- 2023_전문대_예체능계열.xlsx
#                 |-- 2024_대학_예체능계열.xlsx
#                 |-- 2024_전문대_예체능계열.xlsx
#             |-- 전처리 후
#                 |-- 2022_대학_예체능계열.xlsx
#                 |-- 2022_전문대_예체능계열.xlsx
#                 |-- 2023_대학_예체능계열.xlsx
#                 |-- 2023_전문대_예체능계열.xlsx
#                 |-- 2024_대학_예체능계열.xlsx
#                 |-- 2024_전문대_예체능계열.xlsx
#         |-- 의학계열
#             |-- 전처리 전
#                 |-- 2022_대학_의학계열.xlsx
#                 |-- 2023_대학_의학계열.xlsx
#                 |-- 2024_대학_의학계열.xlsx
#             |-- 전처리 후
#                 |-- 2022_대학_의학계열.xlsx
#                 |-- 2023_대학_의학계열.xlsx
#                 |-- 2024_대학_의학계열.xlsx
#         |-- 인문사회계열
#             |-- 전처리 전
#                 |-- 2022_대학_인문사회계열.xlsx
#                 |-- 2022_전문대_인문사회계열.xlsx
#                 |-- 2023_대학_인문사회계열.xlsx
#                 |-- 2023_전문대_인문사회계열.xlsx
#                 |-- 2024_대학_인문사회계열.xlsx
#                 |-- 2024_전문대_인문사회계열.xlsx
#             |-- 전처리 후
#                 |-- 2022_대학_인문사회계열.xlsx
#                 |-- 2022_전문대_인문사회계열.xlsx
#                 |-- 2023_대학_인문사회계열.xlsx
#                 |-- 2023_전문대_인문사회계열.xlsx
#                 |-- 2024_대학_인문사회계열.xlsx
#                 |-- 2024_전문대_인문사회계열.xlsx
#         |-- 자연과학계열
#             |-- 전처리 전
#                 |-- 2022_대학_자연과학계열.xlsx
#                 |-- 2022_전문대_자연과학계열.xlsx
#                 |-- 2023_대학_자연과학계열.xlsx
#                 |-- 2023_전문대_자연과학계열.xlsx
#                 |-- 2024_대학_자연과학계열.xlsx
#                 |-- 2024_전문대_자연과학계열.xlsx
#             |-- 전처리 후
#                 |-- 2022_대학_자연과학계열.xlsx
#                 |-- 2022_전문대_자연과학계열.xlsx
#                 |-- 2023_대학_자연과학계열.xlsx
#                 |-- 2023_전문대_자연과학계열.xlsx
#                 |-- 2024_대학_자연과학계열.xlsx
#                 |-- 2024_전문대_자연과학계열.xlsx
#     |-- 중도탈락 학생 현황_학교별평균값
#         |-- 전처리 전
#             |-- 2022_대학_학교별.xlsx
#             |-- 2022_전문대_학교별.xlsx
#             |-- 2023_대학_학교별.xlsx
#             |-- 2023_전문대_학교별.xlsx
#             |-- 2024_대학_학교별.xlsx
#             |-- 2024_전문대_학교별.xlsx
#         |-- 전처리 후
#             |-- 2022_대학_학교별_전처리.xlsx
#             |-- 2022_전문대_학교별.xlsx
#             |-- 2023_대학_학교별_전처리.xlsx
#             |-- 2023_전문대_학교별.xlsx
#             |-- 2024_대학_학교별_전처리.xlsx
#             |-- 2024_전문대_학교별.xlsx
# |-- 분석.ipynb
# |-- 전처리_학과별.ipynb
# |-- 전처리_학교별.ipynb

# %%
import os
import pandas as pd

def check_columns(folder_path):
    file_list = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]
    columns_set = []
    
    for file_name in file_list:
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_excel(file_path, nrows=1)  # 빠른 로딩을 위해 1줄만 읽음
        columns_set.append((file_name, df.columns.tolist()))
    
    base_cols = columns_set[0][1]
    all_same = True
    
    for file_name, cols in columns_set:
        if cols != base_cols:
            all_same = False
            print(f"[❌ 다른 컬럼 구조] 파일명: {file_name}")
            print(f"현재 파일 컬럼: {cols}")
            print(f"기준 컬럼: {base_cols}")
            print("-" * 80)
    
    if all_same:
        print("[✅ 모든 파일 컬럼 동일]")
        print(f"공통 컬럼: {base_cols}")
    print("=" * 100)
    
# 1. 중도탈락 학생 현황_학교별평균값
print(">> 중도탈락 학생 현황_학교별평균값/전처리 후")
folder_path_school = './데이터/중도탈락 학생 현황_학교별평균값/전처리 후'
check_columns(folder_path_school)

# 2. 중도탈락 학생 현황_학과별 (소속없음 제외)
departments = ['공학계열', '예체능계열', '의학계열', '인문사회계열', '자연과학계열']

for dept in departments:
    print(f">> 중도탈락 학생 현황_학과별/{dept}/전처리 후")
    folder_path_dept = f'./데이터/중도탈락 학생 현황_학과별/{dept}/전처리 후'
    check_columns(folder_path_dept)
# Out:
# >> 중도탈락 학생 현황_학교별평균값/전처리 후
# [✅ 모든 파일 컬럼 동일]
# 공통 컬럼: ['기준연도', '학교종류', '설립구분', '지역', '학교명', '재적학생', '자퇴학생', '자퇴학생비율', '신입생_자퇴학생', '신입생_자퇴학생비율']
# ====================================================================================================
# >> 중도탈락 학생 현황_학과별/공학계열/전처리 후
# [✅ 모든 파일 컬럼 동일]
# 공통 컬럼: ['기준연도', '학교종류', '설립구분', '지역', '학교명', '학과', '재적학생', '자퇴학생', '자퇴학생비율']
# ====================================================================================================
# >> 중도탈락 학생 현황_학과별/예체능계열/전처리 후
# [✅ 모든 파일 컬럼 동일]
# 공통 컬럼: ['기준연도', '학교종류', '설립구분', '지역', '학교명', '학과', '재적학생', '자퇴학생', '자퇴학생비율']
# ====================================================================================================
# >> 중도탈락 학생 현황_학과별/의학계열/전처리 후
# [✅ 모든 파일 컬럼 동일]
# 공통 컬럼: ['기준연도', '학교종류', '설립구분', '지역', '학교명', '학과', '재적학생', '자퇴학생', '자퇴학생비율']
# ====================================================================================================
# >> 중도탈락 학생 현황_학과별/인문사회계열/전처리 후
# [✅ 모든 파일 컬럼 동일]
# 공통 컬럼: ['기준연도', '학교종류', '설립구분', '지역', '학교명', '학과', '재적학생', '자퇴학생', '자퇴학생비율']
# ====================================================================================================
# >> 중도탈락 학생 현황_학과별/자연과학계열/전처리 후
# [✅ 모든 파일 컬럼 동일]
# 공통 컬럼: ['기준연도', '학교종류', '설립구분', '지역', '학교명', '학과', '재적학생', '자퇴학생', '자퇴학생비율']
# ====================================================================================================
